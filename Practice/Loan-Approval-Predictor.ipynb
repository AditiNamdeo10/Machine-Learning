# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC

data={"Income": [30000,35000,50000,60000,70000],
      "CreditScore": [550,600,700,750,800],
      "Approved": [0,0,1,1,1]
}

df=pd.DataFrame(data)

X=df[["Income","CreditScore"]]
y=df["Approved"]

scaler=StandardScaler()
X_scaled=scaler.fit_transform(X)

model=SVC(kernel="linear")
model.fit(X_scaled,y)

new_data=scaler.transform([[55000,720]])
pred=model.predict(new_data)

print(pred)
# Out:
# [1]
# c:\Users\avadh\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
